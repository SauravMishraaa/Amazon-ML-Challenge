# %%
#importing the desired libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading the dataset
dataset=pd.read_csv("train.csv")

# %%
#splitting the training and testing data
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
#to view the original dataset
print(dataset)
# Out:
#          PRODUCT_ID                                              TITLE  \
# 0           1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1           2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4            283658  The United Empire Loyalists: A Chronicle of th...
# ...             ...                                                ...
# 2249693     2422167  Nike Women's As W Ny Df Swsh Hn Kh Bra (CZ7610...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249696     1165754  Electro Voice EKX-BRKT15 | Wall Mount Bracket ...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# 0        [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1        [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2        [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3        [Made By 95%cotton and 5% Lycra which gives yo...
# 4                                                      NaN
# ...                                                    ...
# 2249693                               Material : Polyester
# 2249694  [❤ [Inspiration] Inspired by the Untitled Goos...
# 2249695  [Dial size: 12 inches in diameter,Big, clear r...
# 2249696                                                NaN
# 2249697  [Component Box For PN[C7360PK],4 in. Lift,Incl...
#
#                                                DESCRIPTION  PRODUCT_TYPE_ID  \
# 0                                                      NaN             1650
# 1                                                      NaN             2755
# 2        Specifications: Color: Red, Material: Aluminiu...             7537
# 3        AISHAH Women's Lycra Cotton Ankel Leggings. Br...             2996
# 4                                                      NaN             6112
# ...                                                    ...              ...
# 2249693                                                NaN             3009
# 2249694  <p><b>[Brand]: </b>XVIEONR</p> <p><br></p> <p>...             3413
# 2249695  Wall Clocks Are Very Attractive In Looks And E...             1574
# 2249696                                                NaN              592
# 2249697  Skyjacker C7360SP Component Box For PN[C7360PK...             7367
#
#          PRODUCT_LENGTH
# 0           2125.980000
# 1            393.700000
# 2            748.031495
# 3            787.401574
# 4            598.424000
# ...                 ...
# 2249693     1181.100000
# 2249694      125.984252
# 2249695     1200.000000
# 2249696     2900.000000
# 2249697     2000.000000
#
# [2249698 rows x 6 columns]

# %%
#to view the dataset
print(x)
# Out:
# [[1925202
#   'ArtzFolio Tulip Flowers Blackout Curtain for Door, Window & Room | Eyelets & Tie Back | Canvas Fabric | Width 4.5feet (54inch) Height 5 feet (60 inch); Set of 2 PCS'
#   '[LUXURIOUS & APPEALING: Beautiful custom-made curtains to decorate any home or office | Includes inbuilt tieback to hold the curtain | Completely finished and ready to hang on walls & windows,MATERIAL: Luxurious & versatile fabric with a natural finish | High colour fastness | State-of-the-art digital printing ensures colour consistency and prevents any fading | Eyelets; Cotton Canvas; Width 4.5feet (54inch) | Multicolour | PACKAGE: 2 Room Curtains Eyelets | SIZE: Height 5 feet (60 inch); SET OF 2 PCS,BLACKOUT CURTAIN: 100% opaque & heavy premium cotton canvas fabric | Tight knitted, long life & durable fabric | Printing only on front side with a plain colour back side,MADE TO PERFECTION: Large eyelets at the top to put hanging hooks | Perfectly tailored seams for durability | Refined stitching with a matching thread color,QUALITY ASSURED: Gentle wash with similar colors in cold water | Avoid direct sunlight to prevent fading | Dispatched after MULTIPLE QUALITY CHECKS]'
#   nan 1650]
#  [2673191 "Marks & Spencer Girls' Pyjama Sets T86_2561C_Navy Mix_9-10Y"
#   '[Harry Potter Hedwig Pyjamas (6-16 Yrs),100% cotton (exclusive of trimmings),Ribbing - 98% cotton, 2% elastane]'
#   nan 2755]
#  [2765088
#   'PRIKNIK Horn Red Electric Air Horn Compressor Interior Dual Tone Trumpet Loud Compatible with SX4'
#   '[Loud Dual Tone Trumpet Horn, Compatible With SX4,Electric Air Horn with Compressor, Compatible With SX4,High Quality, High Intensity Horn Sound, Compatible With SX4,Color: Red, Compatible With SX4,Professional installation required, Compatible With SX4]'
#   'Specifications: Color: Red, Material: Aluminium, Voltage: 12V, dB: 130 dB (around), Material: Aluminum Pump Head + Steel Pump Body + ABS Shell and Parts DB output: 130db Voltage: 12v Sound Type: Dual Tone Application: 12V Voltage Vehicles With Battery Above 20A Package included: 1 x Dual Tone Air Horn Compatible With SX4'
#   7537]
#  ...
#  [1987786
#   'Kangroo Sweep Movement Printed Wooden Wall Clock for Home (12 x 12 Inch)'
#   '[Dial size: 12 inches in diameter,Big, clear representation of the numbers on the clock,Sweep and silent movement clock, which requires one AA battery (Not included). Without Glass,1 year limited warranty on the product from the date of invoice,Its Wall Clock design and manufacture by Kangroo. We are responsible for any technical issue of this product. Clock warranty is six months. You can contact personally after ended Amazon return period for replacement. We are happy to help you]'
#   'Wall Clocks Are Very Attractive In Looks And Easy To Handle From A Wide Variety Of Vintage Clocks We Provide You Some Of The Master Pieces Which Can Ever Let You Regret On Your Purchase. These Wall Clocks Are Designed With Perfection And Decorated With Charm To Provide Your Interior A Very Elite Appeal and Easy To Clean With Dry Cloth. The clock works on a single battery and has a very good quality built and make the looks and ambiance of your home and office a worth looking at.'
#   1574]
#  [1165754
#   'Electro Voice EKX-BRKT15 | Wall Mount Bracket for EKX-15 EKX-15P Black'
#   nan nan 592]
#  [1072666
#   'Skyjacker C7360SP Component Box For PN[C7360PK] 4 in. Lift Incl. Front Spacers Hardware Component Box For PN[C7360PK]'
#   '[Component Box For PN[C7360PK],4 in. Lift,Incl. Front Spacers,Hardware]'
#   'Skyjacker C7360SP Component Box For PN[C7360PK]; Lift Kit-Suspension Component'
#   7367]]

# %%
#to view the result 
print(y)
# Out:
# [2125.98       393.7        748.0314953 ... 1200.        2900.
#  2000.       ]

# %%
#to count the number of missing data in our dataset
print(dataset.isnull().sum())
# Out:
# PRODUCT_ID               0
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
# replacing the missing data with the averege value of the column
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer = imputer.fit(dataset)
dataset.iloc[:,:] = imputer.transform(dataset)
print(dataset)
# Out:
#          PRODUCT_ID                                              TITLE  \
# 0           1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1           2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4            283658  The United Empire Loyalists: A Chronicle of th...
# ...             ...                                                ...
# 2249693     2422167  Nike Women's As W Ny Df Swsh Hn Kh Bra (CZ7610...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249696     1165754  Electro Voice EKX-BRKT15 | Wall Mount Bracket ...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# 0        [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1        [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2        [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3        [Made By 95%cotton and 5% Lycra which gives yo...
# 4        [Good quality and Suitable to use.,This Produc...
# ...                                                    ...
# 2249693                               Material : Polyester
# 2249694  [❤ [Inspiration] Inspired by the Untitled Goos...
# 2249695  [Dial size: 12 inches in diameter,Big, clear r...
# 2249696  [Good quality and Suitable to use.,This Produc...
# 2249697  [Component Box For PN[C7360PK],4 in. Lift,Incl...
#
#                                                DESCRIPTION  PRODUCT_TYPE_ID  \
# 0        This Case is Made up of Hard Polycarbonate Pla...             1650
# 1        This Case is Made up of Hard Polycarbonate Pla...             2755
# 2        Specifications: Color: Red, Material: Aluminiu...             7537
# 3        AISHAH Women's Lycra Cotton Ankel Leggings. Br...             2996
# 4        This Case is Made up of Hard Polycarbonate Pla...             6112
# ...                                                    ...              ...
# 2249693  This Case is Made up of Hard Polycarbonate Pla...             3009
# 2249694  <p><b>[Brand]: </b>XVIEONR</p> <p><br></p> <p>...             3413
# 2249695  Wall Clocks Are Very Attractive In Looks And E...             1574
# 2249696  This Case is Made up of Hard Polycarbonate Pla...              592
# 2249697  Skyjacker C7360SP Component Box For PN[C7360PK...             7367
#
#          PRODUCT_LENGTH
# 0           2125.980000
# 1            393.700000
# 2            748.031495
# 3            787.401574
# 4            598.424000
# ...                 ...
# 2249693     1181.100000
# 2249694      125.984252
# 2249695     1200.000000
# 2249696     2900.000000
# 2249697     2000.000000
#
# [2249698 rows x 6 columns]

# %%
#to count the number of missing data in our dataset
print(dataset.isnull().sum())
# Out:
# PRODUCT_ID         0
# TITLE              0
# BULLET_POINTS      0
# DESCRIPTION        0
# PRODUCT_TYPE_ID    0
# PRODUCT_LENGTH     0
# dtype: int64

# %%
#using nlp to clean the text the bulletpoints
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 1000):
  bp = re.sub('[^a-zA-Z]', ' ', dataset['BULLET_POINTS'][i])
  bp = bp.lower()
  bp = bp.split()
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  bp = [ps.stem(word) for word in bp if not word in set(all_stopwords)]
  review = ' '.join(bp)
  corpus.append(bp)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# [['luxuri', 'appeal', 'beauti', 'custom', 'made', 'curtain', 'decor', 'home', 'offic', 'includ', 'inbuilt', 'tieback', 'hold', 'curtain', 'complet', 'finish', 'readi', 'hang', 'wall', 'window', 'materi', 'luxuri', 'versatil', 'fabric', 'natur', 'finish', 'high', 'colour', 'fast', 'state', 'art', 'digit', 'print', 'ensur', 'colour', 'consist', 'prevent', 'fade', 'eyelet', 'cotton', 'canva', 'width', 'feet', 'inch', 'multicolour', 'packag', 'room', 'curtain', 'eyelet', 'size', 'height', 'feet', 'inch', 'set', 'pc', 'blackout', 'curtain', 'opaqu', 'heavi', 'premium', 'cotton', 'canva', 'fabric', 'tight', 'knit', 'long', 'life', 'durabl', 'fabric', 'print', 'front', 'side', 'plain', 'colour', 'back', 'side', 'made', 'perfect', 'larg', 'eyelet', 'top', 'put', 'hang', 'hook', 'perfectli', 'tailor', 'seam', 'durabl', 'refin', 'stitch', 'match', 'thread', 'color', 'qualiti', 'assur', 'gentl', 'wash', 'similar', 'color', 'cold', 'water', 'avoid', 'direct', 'sunlight', 'prevent', 'fade', 'dispatch', 'multipl', 'qualiti', 'check'], ['harri', 'potter', 'hedwig', 'pyjama', 'yr', 'cotton', 'exclus', 'trim', 'rib', 'cotton', 'elastan'], ['loud', 'dual', 'tone', 'trumpet', 'horn', 'compat', 'sx', 'electr', 'air', 'horn', 'compressor', 'compat', 'sx', 'high', 'qualiti', 'high', 'intens', 'horn', 'sound', 'compat', 'sx', 'color', 'red', 'compat', 'sx', 'profession', 'instal', 'requir', 'compat', 'sx'], ['made', 'cotton', 'lycra', 'give', 'way', 'stretchabl', 'comfort', 'gsm', 'come', 'elastic', 'waist', 'band', 'slim', 'fit', 'bubbl', 'free', 'fabric', 'high', 'qualiti', 'steach', 'bio', 'wash', 'skin', 'friendli', 'fabric', 'ankl', 'length', 'leg', 'pack'], ['good', 'qualiti', 'suitabl', 'use', 'product', 'come', 'proper', 'packag', 'case', 'queri', 'issu', 'feel', 'free', 'reach', 'us', 'contain', 'pack', 'deliveri', 'within', 'week'], ['simpl', 'eleg', 'great', 'display', 'indoor', 'plant', 'like', 'succul', 'plant', 'air', 'plant', 'seedl', 'herb', 'etc', 'high', 'qualiti', 'indoor', 'outdoor', 'planter', 'stand', 'flower', 'pot', 'made', 'wrought', 'iron', 'materi', 'powder', 'coat', 'paint', 'rustproof', 'durabl', 'pefect', 'decor', 'live', 'room', 'balconi', 'garden', 'best', 'qualiti', 'strong', 'durabl', 'surfac', 'pot', 'holder', 'rust', 'proof', 'use', 'longer', 'time', 'elev', 'indoor', 'pot', 'plant', 'stand', 'make', 'water', 'easier', 'give', 'plant', 'better', 'space', 'grow', 'pragmat', 'eco', 'friendli', 'gift', 'natur', 'lover', 'garden', 'hobbyist', 'home', 'decorist', 'note', 'plant', 'display', 'not', 'includ', 'planter', 'pleas', 'allow', 'cm', 'error', 'due', 'manual', 'measur'], ['good', 'qualiti', 'suitabl', 'use', 'product', 'come', 'proper', 'packag', 'case', 'queri', 'issu', 'feel', 'free', 'reach', 'us', 'contain', 'pack', 'deliveri', 'within', 'week'], ['high', 'qualiti', 'pvc', 'materi', 'kitchen', 'aluminum', 'foil', 'sticker', 'made', 'plastic', 'aluminum', 'foil', 'much', 'stronger', 'high', 'temperatur', 'normal', 'pvc', 'sheet', 'anti', 'bacteri', 'anti', 'mold', 'eco', 'friendli', 'pvc', 'materi', 'safe', 'enough', 'use', 'kitchen', 'easi', 'use', 'clean', 'self', 'adhes', 'kitchen', 'wallpap', 'easi', 'stick', 'dri', 'clean', 'smooth', 'surfac', 'anti', 'oil', 'anti', 'dust', 'anti', 'water', 'anti', 'moistur', 'pvc', 'materi', 'allow', 'wipe', 'stain', 'easili', 'easi', 'cut', 'trim', 'back', 'cut', 'fit', 'grid', 'line', 'design', 'self', 'adhes', 'kitchen', 'oil', 'proof', 'sticker', 'conveni', 'cut', 'trim', 'size', 'want', 'silver', 'rhombu', 'textur', 'add', 'fashion', 'kitchen', 'decor', 'multi', 'usag', 'kitchen', 'backsplash', 'wallpap', 'great', 'home', 'decor', 'use', 'kitchen', 'cabinet', 'countertop', 'shelv', 'wall', 'pantri', 'area', 'dishwash', 'dishwash', 'panel', 'oven', 'hood', 'refriger', 'applianc', 'etc', 'instant', 'peel', 'appli', 'flat', 'surfac', 'anti', 'oil', 'anti', 'dust', 'anti', 'water', 'made', 'plastic', 'aluminum', 'foil', 'much', 'stronger', 'fire', 'normal', 'pvc', 'she ...

# %%
#using nlp to clean the decsription
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus1 = []
for i in range(0, 1000):
  dp = re.sub('[^a-zA-Z]', ' ', dataset['DESCRIPTION'][i])
  dp = dp.lower()
  dp = dp.split()
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  dp = [ps.stem(word) for word in dp if not word in set(all_stopwords)]
  review = ' '.join(dp)
  corpus1.append(dp)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus1)
# Out:
# [['case', 'made', 'hard', 'polycarbon', 'plastic', 'print', 'side', 'back', 'cover', 'cover', 'protect', 'mobil', 'scratch', 'bump', 'print', 'case', 'give', 'premier', 'look', 'mobil'], ['case', 'made', 'hard', 'polycarbon', 'plastic', 'print', 'side', 'back', 'cover', 'cover', 'protect', 'mobil', 'scratch', 'bump', 'print', 'case', 'give', 'premier', 'look', 'mobil'], ['specif', 'color', 'red', 'materi', 'aluminium', 'voltag', 'v', 'db', 'db', 'around', 'materi', 'aluminum', 'pump', 'head', 'steel', 'pump', 'bodi', 'ab', 'shell', 'part', 'db', 'output', 'db', 'voltag', 'v', 'sound', 'type', 'dual', 'tone', 'applic', 'v', 'voltag', 'vehicl', 'batteri', 'packag', 'includ', 'x', 'dual', 'tone', 'air', 'horn', 'compat', 'sx'], ['aishah', 'women', 'lycra', 'cotton', 'ankel', 'leg', 'brand', 'alishah', 'length', 'ankel', 'length', 'leg', 'size', 'chart', 'medium', 'inch', 'larg', 'inch', 'x', 'larg', 'inch', 'x', 'larg', 'inch', 'color', 'fade', 'not', 'wash', 'cotton', 'stretch', 'leg', 'design', 'provid', 'absolut', 'comfort', 'bodi', 'fit', 'pair', 'short', 'long', 'kurta', 'modern', 'look', 'high', 'style', 'fit', 'finish', 'leg', 'sure', 'lend', 'sophist', 'look', 'pleas', 'wash', 'dark', 'color', 'separ', 'order', 'improv', 'product', 'life', 'disclaim', 'product', 'color', 'may', 'slightli', 'vari', 'due', 'photograph', 'light', 'sourc', 'monitor', 'set', 'pleas', 'order', 'accord', 'waist', 'size', 'mention', 'size', 'chart'], ['case', 'made', 'hard', 'polycarbon', 'plastic', 'print', 'side', 'back', 'cover', 'cover', 'protect', 'mobil', 'scratch', 'bump', 'print', 'case', 'give', 'premier', 'look', 'mobil'], ['hin', 'bring', 'eleg', 'look', 'pot', 'stand', 'durabl', 'long', 'life', 'pot', 'stand', 'love', 'garden', 'space', 'offic', 'home', 'hin', 'one', 'best', 'choic', 'come', 'indoor', 'plant', 'make', 'good', 'choic', 'housewarm', 'gift', 'beauti', 'product', 'take', 'center', 'stage', 'sprawl', 'design', 'plant', 'plant', 'metal', 'stand', 'paint', 'powder', 'coat', 'paint', 'protect', 'galvan', 'iron', 'rust', 'also', 'prevent', 'color', 'fade', 'planter', 'pot', 'remov', 'easi', 'mobil', 'allow', 'switch', 'plant', 'depend', 'mood', 'note', 'monitor', 'not', 'calibr', 'item', 'color', 'display', 'photo', 'may', 'show', 'slightli', 'differ', 'real', 'object', 'pleas', 'take', 'real', 'one', 'standard', 'pleas', 'allow', 'cm', 'error', 'due', 'manual', 'measur'], ['case', 'made', 'hard', 'polycarbon', 'plastic', 'print', 'side', 'back', 'cover', 'cover', 'protect', 'mobil', 'scratch', 'bump', 'print', 'case', 'give', 'premier', 'look', 'mobil'], ['p', 'strong', 'aluminum', 'foil', 'sticker', 'good', 'kitchen', 'helper', 'mom', 'wife', 'nbsp', 'strong', 'br', 'br', 'strong', 'specif', 'nbsp', 'strong', 'br', 'strong', 'materi', 'high', 'qualiti', 'pvc', 'nbsp', 'strong', 'br', 'strong', 'size', 'mt', 'nbsp', 'strong', 'br', 'strong', 'color', 'silver', 'nbsp', 'strong', 'br', 'strong', 'friendli', 'note', 'pleas', 'buy', 'enough', 'roll', 'time', 'make', 'sure', 'wallpap', 'come', 'batch', 'avoid', 'color', 'differ', 'nbsp', 'strong', 'br', 'strong', 'aluminum', 'foil', 'sticker', 'use', 'dri', 'clean', 'smooth', 'surfac', 'nbsp', 'strong', 'br', 'br', 'strong', 'featur', 'nbsp', 'strong', 'br', 'strong', 'high', 'temperatur', 'resist', 'materi', 'suitabl', 'kitchen', 'resist', 'temperatur', 'celsiu', 'use', 'long', 'time', 'not', 'deform', 'nbsp', 'strong', 'br', 'strong', 'easili', 'cut', 'grid', 'line', 'squar', 'back', 'easi', 'get', 'size', 'need', 'cut', 'nbsp', 'strong', 'br', 'br', 'strong', 'use', 'nbsp', 'strong', 'br', 'strong', 'stick', 'kitchen', 'oil', 'proof', 'wallpap', 'pleas', 'clean', 'dri', 'surfac', 'mild', 'soap', 'water', 'make', 'sure', 'surfac', 'flat', 'without', 'carv', 'nbsp', 'strong', 'br', 'strong', 'cut', 'size', 'want', 'nbsp', 'strong', 'br', 'strong', 'use', 'dishcloth', 'card', 'remov', 'air', 'bubbl', 'nbsp', 'strong', 'br', 'br', 'strong', 'packag', 'includ', 'nbsp', 'strong', 'br ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [91], in <cell line: 3>()
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 cv = CountVectorizer(max_features = 1500)
# ----> 3 X = cv.fit_transform(corpus).toarray()
#
# File c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:1338, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1330             warnings.warn(
#    1331                 "Upper case characters found in"
#    1332                 " vocabulary while 'lowercase'"
#    1333                 " is True. These entries will not"
#    1334                 " be matched with any documents"
#    1335             )
#    1336             break
# -> 1338 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1340 if self.binary:
#    1341     X.data.fill(1)
#
# File c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:1209, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1207 for doc in raw_documents:
#    1208     feature_counter = {}
# -> 1209     for feature in analyze(doc):
#    1210         try:
#    1211             feature_idx = vocabulary[feature]
#
# File c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:111, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     109 else:
#     110     if preprocessor is not None:
# --> 111         doc = preprocessor(doc)
#     112     if tokenizer is not None:
#     113         doc = tokenizer(doc)
#
# File c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:69, in _preprocess(doc, accent_function, lower)
#      50 """Chain together an optional series of text preprocessing steps to
#      51 apply to a document.
#      52
#    (...)
#      66     preprocessed string
#      67 """
#      68 if lower:
# ---> 69     doc = doc.lower()
#      70 if accent_function is not None:
#      71     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'
